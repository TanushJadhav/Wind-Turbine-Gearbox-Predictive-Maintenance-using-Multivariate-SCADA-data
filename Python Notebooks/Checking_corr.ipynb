# %%
import pandas as pd

# %%
df = pd.read_csv("../Datasets/2020/Turbine_Data_Kelmarsh_1_2020-01-01_-_2021-01-01_228.csv")
df
# Out:
#           Date and time  Wind speed (m/s)  \
# 0      01-01-2020 00:00          3.887291
# 1      01-01-2020 00:10          3.848941
# 2      01-01-2020 00:20          4.043625
# 3      01-01-2020 00:30          3.330342
# 4      01-01-2020 00:40          3.388536
# ...                 ...               ...
# 52699  31-12-2020 23:10          5.119444
# 52700  31-12-2020 23:20          5.009681
# 52701  31-12-2020 23:30          5.060813
# 52702  31-12-2020 23:40          4.814269
# 52703  31-12-2020 23:50          5.477400
#
#        Wind speed, Standard deviation (m/s)  Wind speed, Minimum (m/s)  \
# 0                                  0.646663                   2.629255
# 1                                  0.787454                   2.456995
# 2                                  0.983279                   2.726894
# 3                                  0.689929                   1.541864
# 4                                  0.897104                   1.832924
# ...

# %%
df.drop("Date and time", axis=1, inplace=True)

# %%
x = df.corr()['Gear oil temperature (°C)']

# %%
d = pd.DataFrame(x)

# %%
for index, row in d.iterrows():
    if row["Gear oil temperature (°C)"] > 0.55:
        print(row)
# Out:
# Gear oil temperature (°C)    0.753455
# Name: Front bearing temperature (°C), dtype: float64
# Gear oil temperature (°C)    0.873076
# Name: Rear bearing temperature (°C), dtype: float64
# Gear oil temperature (°C)    0.55947
# Name: Stator temperature 1 (°C), dtype: float64
# Gear oil temperature (°C)    0.766458
# Name: Gear oil inlet temperature (°C), dtype: float64
# Gear oil temperature (°C)    0.580527
# Name: Generator bearing rear temperature (°C), dtype: float64
# Gear oil temperature (°C)    0.650274
# Name: Generator bearing front temperature (°C), dtype: float64
# Gear oil temperature (°C)    1.0
# Name: Gear oil temperature (°C), dtype: float64
# Gear oil temperature (°C)    0.691537
# Name: Rotor bearing temp (°C), dtype: float64
# Gear oil temperature (°C)    0.762001
# Name: Front bearing temperature, Max (°C), dtype: float64
# Gear oil temperature (°C)    0.741621
# Name: Front bearing temperature, Min (°C), dtype: float64
# Gear oil temperature (°C)    0.873852
# ...

# %% [markdown]
# Front bearing temperature (°C)
# Rear bearing temperature (°C)
# Gear oil inlet temperature (°C)
# Generator bearing front temperature (°C)
# Rotor bearing temp (°C)
