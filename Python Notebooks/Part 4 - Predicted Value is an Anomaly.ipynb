# %%
import os
import pandas as pd
import numpy as np
from keras.models import model_from_json

# %%
def data_into_timeseries(df):
    for i in df.columns:
        data = pd.DataFrame(df[i])
        data.index = df.index
        data.rename(columns={i:'y'}, inplace=True)
        data['x1']= data['y'].shift()
        data['x2']= data['y'].shift(2)
        data['x3']= data['y'].shift(3)
        data['x4']= data['y'].shift(4)
        data['x5']= data['y'].shift(5)
        data['x6']= data['y'].shift(6)

        data = data.iloc[6:]
        
        data.to_csv("../Datasets/Timeseries Data/Test/" + i + ".csv")
        
        print("Saved", i + ".csv")

# %%
# data_into_timeseries(test_df)

# %%
def check_anomaly(dataset_path, threshold):
    threshold=threshold*2
    for i in ["Generator bearing front temperature (°C).csv", "Generator bearing rear temperature (°C).csv", "Rotor bearing temp (°C).csv"]:
        df = pd.read_csv(dataset_path+i).values

        file = open('../Model Files/LSTM Model/model.json', 'r')
        loaded  = file.read()
        file.close()
        model = model_from_json(loaded)
        model.load_weights("../Model Files/LSTM Model/" + i + ".h5")
        
        for j in  df:
            dateTime = j[0]
            y = j[1]
            x = list(j[2:])
            pred = model.predict([[x]])[0][0]
            
            if pred > np.mean(x)*threshold:
                print("Anomaly Detected at", dateTime, "Predicted Temp:", pred)

# %%
check_anomaly(dataset_path="../Datasets/Timeseries Data/Test/", threshold=1.045881)
# Out:
# ...
# 1/1 [==============================] - 0s 32ms/step
# Anomaly Detected at 01-01-2021 17:10 Predicted Temp: 35.265003 Actual Temp: 36.26000004
# 1/1 [==============================] - 0s 64ms/step
# Anomaly Detected at 01-01-2021 17:20 Predicted Temp: 41.37637 Actual Temp: 40.73250008
# ...
# 1/1 [==============================] - 0s 30ms/step
# ...
# ...
# 1/1 [==============================] - 0s 32ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 check_anomaly(dataset_path="../Datasets/Timeseries Data/Test/", threshold=1.045881)
#
# Cell In[6], line 16, in check_anomaly(dataset_path, threshold)
#      14 y = j[1]
#      15 x = list(j[2:])
# ---> 16 pred = model.predict([[x]])[0][0]
#      18 if pred > np.mean(x)*threshold:
#      19     print("Anomaly Detected at", dateTime, "Predicted Temp:", pred, "Actual Temp:", y)
#
# ...
