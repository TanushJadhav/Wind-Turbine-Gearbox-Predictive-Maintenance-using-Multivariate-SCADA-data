# %%
import os
import pandas as pd
import numpy as np
from keras.models import model_from_json

# %%
def data_into_timeseries(df):
    for i in df.columns:
        data = pd.DataFrame(df[i])
        data.index = df.index
        data.rename(columns={i:'y'}, inplace=True)
        data['x1']= data['y'].shift()
        data['x2']= data['y'].shift(2)
        data['x3']= data['y'].shift(3)
        data['x4']= data['y'].shift(4)
        data['x5']= data['y'].shift(5)
        data['x6']= data['y'].shift(6)

        data = data.iloc[6:]
        
        data.to_csv("../Datasets/Timeseries Data/Test/" + i + ".csv")
        
        print("Saved", i + ".csv")

# %%
# data_into_timeseries(test_df)

# %%
def check_anomaly(dataset_path, threshold):
    threshold=threshold*2
    for i in ["Generator bearing front temperature (°C).csv", "Generator bearing rear temperature (°C).csv", "Rotor bearing temp (°C).csv"]:
        df = pd.read_csv(dataset_path+i).values

        file = open('../Model Files/LSTM Model/model.json', 'r')
        loaded  = file.read()
        file.close()
        model = model_from_json(loaded)
        model.load_weights("../Model Files/LSTM Model/" + i + ".h5")
        
        for j in  df:
            dateTime = j[0]
            y = j[1]
            x = list(j[2:])
            
            pred = model.predict([[x]])[0][0]
            
            if pred-y > threshold:
                print("Anomaly Detected at", dateTime, "Predicted Temp:", pred, "Actual Temp:", y)

# %%
check_anomaly(dataset_path="../Datasets/Timeseries Data/Test/", threshold=1.353)
# Out:
# ...
# 1/1 [==============================] - 0s 29ms/step
# Anomaly Detected at 01-01-2021 17:40 Predicted Temp: 47.541054 Actual Temp: 44.63250027
# ...
# 1/1 [==============================] - 0s 33ms/step
# Anomaly Detected at 01-01-2021 18:00 Predicted Temp: 45.245632 Actual Temp: 42.32250004
# ...
# 1/1 [==============================] - 0s 31ms/step
# Anomaly Detected at 01-01-2021 23:00 Predicted Temp: 46.672375 Actual Temp: 42.81749992
# ...
# 1/1 [==============================] - 0s 30ms/step
# Anomaly Detected at 02-01-2021 03:40 Predicted Temp: 44.459263 Actual Temp: 41.35526336
# ...
# 1/1 [==============================] - 0s 29ms/step
# Anomaly Detected at 02-01-2021 04:50 Predicted Temp: 40.99196 Actual Temp: 37.11999989
# ...
# 1/1 [==============================] - 0s 30ms/step
# Anomaly Detected at 02-01-2021 07:10 Predicted Temp: 42.22235 Actual Temp: 38.49249973
# ...
# 1/1 [==============================] - 0s 30ms/step
# ...
